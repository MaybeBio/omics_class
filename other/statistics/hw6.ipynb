# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 一，实践：《An Introduction to Statistical Learning》Section 6.5 Lab: Linear models and regularization methods

# %% [markdown]
# 1，Subset Selection Methods

# %% [markdown]
# Best Subset Selection
